# %%
from reaction_network_graph import Species

cpe = Species(name="CPE", smiles="C1CCC=C1")
oh = Species(name="OH", smiles="[OH]")
cpe_oh = Species(name="CPE.OH", smiles="C1CCC=C1.[OH]")
cpa2y0 = Species(name="CPA2Y0", smiles="C1CC[CH][C@H]1O")
cpa2y1 = Species(name="CPA2Y1", smiles="C1CC[CH][C@@H]1O")
cpa1y = Species(name="CPA1Y", smiles="C1CCC[C]1O")
cpo = Species(name="CPO", smiles="C1CCC1=O")
h = Species(name="H", smiles="[H]")

# %%
from reaction_network_graph import Stage

cpe_p_oh_st = Stage(name="CPE+OH", species=[cpe, oh])
cpe_oh_st = Stage(name="CPE.OH", species=[cpe_oh])
cpa2y0_st = Stage(name="CPA2Y0", species=[cpa2y0])
cpa2y1_st = Stage(name="CPA2Y1", species=[cpa2y1])
cpa1y_st = Stage(name="CPA1Y", species=[cpa1y])
cpo_p_h_st = Stage(name="CPO+H", species=[cpo, h])
# Out:
# Stage(name='CPO+H', label=None, energy=None, species=(Species(name='CPO', formula=None, charge=0, multiplicity=None, smiles='C1CCC1=O'), Species(name='H', formula=None, charge=0, multiplicity=None, smiles='[H]')))
